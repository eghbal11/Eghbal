# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
from sklearn.metrics import mean_squared_error
color_pal = sns.color_palette()

# %%
def print_metrics(y_test, y_pred,y_label, alg_name, dataset_name):

    # Calculate RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    print(f'RMSE Score on Test set: {rmse:.2f}')

    # Mean Absolute Error (MAE)
    mae = np.mean(np.abs(y_test - y_pred.reshape(y_pred.shape[0])))
    print(f'mae Score on Test set: {mae:.2f}')

    # R-squared (R2) Score
    mean_actual = np.mean(y_test)
    total_sum_of_squares = np.sum((y_test - mean_actual) ** 2)
    residual_sum_of_squares = np.sum((y_test - y_pred.reshape(y_pred.shape[0])) ** 2)
    r2 = 1 - (residual_sum_of_squares / total_sum_of_squares)
    print(f'r2 Score on Test set: {r2:.2f}')

    # Mean Bias Deviation (MBE):
    mbe = np.mean(y_test - y_pred.reshape(y_pred.shape[0]))
    print(f'mbe Score on Test set: {mbe:.2f}')

    # Median Absolute Error (MedAE):
    medae = np.median(np.abs(y_test - y_pred.reshape(y_pred.shape[0])))
    print(f'medae Score on Test set: {medae:.2f}')

    # Coefficient of Determination (COD):
    mean_actual = np.mean(y_test)
    total_sum_of_squares = np.sum((y_test - mean_actual) ** 2)
    residual_sum_of_squares = np.sum((y_test - y_pred.reshape(y_pred.shape[0])) ** 2)
    cod = 1 - (residual_sum_of_squares / total_sum_of_squares)
    print(f'cod Score on Test set: {cod:.2f}')

    # Explained Variance Score:
    explained_variance = 1 - (np.var(y_test - y_pred.reshape(y_pred.shape[0])) / np.var(y_test))
    print(f'explained_variance Score on Test set: {explained_variance:.2f}')

    # Relative Absolute Error (RAE):
    mae = np.mean(np.abs(y_test - y_pred.reshape(y_pred.shape[0])))
    baseline_mae = np.mean(np.abs(y_test - np.mean(y_test)))
    rae = mae / baseline_mae
    print(f'rae Score on Test set: {rae:.2f}')

    with open(f'./metrics-{alg_name}-{dataset_name}.txt','w') as f:
        txt = f"rmse: {rmse}"+'\n'+ f"mae: {mae}"+'\n'+f"r2: {r2}"+'\n'+f"medae: {medae}"+'\n'+f"cod: {cod}"+'\n'+f"explained_variance: {explained_variance}"+'\n'+f"rae: {rae}"+'\n'
        f.write(txt)

# %%
def plot_act_vs_pred(y_test, y_pred,y_label, alg_name, dataset_name):
    print_metrics(y_test, y_pred,y_label, alg_name, dataset_name)
    # Plot predictions vs. actual values
    plt.figure(figsize=(8, 3),)
    plt.plot(test.index, y_test, label='Actual', color='blue')
    plt.plot(test.index, y_pred, label='Predicted', color='red')
    plt.title(f'Actual vs. Predicted - {alg_name} - {dataset_name}')
    plt.xlabel('Date')
    plt.ylabel(y_label)
    plt.legend()
    plt.savefig(f"Actual vs. Predicted - {alg_name}' - {dataset_name}.png")
    plt.savefig(f"Actual vs. Predicted - {alg_name}' - {dataset_name}.svg", format='svg', dpi=1200, bbox_inches='tight', facecolor='white')
    plt.show()

# %%
dataset_name = 'pf_filled'
df = pd.read_csv(f'/content/drive/MyDrive/datasets (1)/time-series-forecasting/{dataset_name}.csv')
df = df.set_index('Time')
selected_column = df.columns[0]
df = df[selected_column]
df.index = pd.to_datetime(df.index)

# %%
df = df.to_frame()

# %%
df
# Out:
#                      prod_k28
# Time
# 2020-12-22 00:00:00       0.0
# 2020-12-22 01:00:00       0.0
# 2020-12-22 02:00:00       0.0
# 2020-12-22 03:00:00       0.0
# 2020-12-22 04:00:00       0.0
# ...                       ...
# 2023-01-10 16:00:00       0.3
# 2023-01-10 17:00:00       0.0
# 2023-01-10 18:00:00       0.0
# 2023-01-10 19:00:00       0.0
# 2023-01-10 20:00:00       0.0
#
# [17997 rows x 1 columns]

# %%
df.columns
# Out:
# Index(['prod_k28'], dtype='object')

# %%
# df = df['prod_k28']

# %%
# df = df.loc[:, 'cons_k28']
# df = df.loc[:, 'prod_k28']

# %%
df
# Out:
#                      prod_k28
# Time
# 2020-12-22 00:00:00       0.0
# 2020-12-22 01:00:00       0.0
# 2020-12-22 02:00:00       0.0
# 2020-12-22 03:00:00       0.0
# 2020-12-22 04:00:00       0.0
# ...                       ...
# 2023-01-10 16:00:00       0.3
# 2023-01-10 17:00:00       0.0
# 2023-01-10 18:00:00       0.0
# 2023-01-10 19:00:00       0.0
# 2023-01-10 20:00:00       0.0
#
# [17997 rows x 1 columns]

# %%
df.plot(style='.',
        figsize=(8, 3),
        color=color_pal[0],
        title=f'{dataset_name} Energy Use in KW')
plt.savefig(f"figure1-{dataset_name}.png")
plt.show()

# %%
# Split data to Train and Test

date = '09-01-2022'
train = df.loc[df.index < date]
test = df.loc[df.index >= date]

# %%
test
# Out:
#                      prod_k28
# Time
# 2022-09-01 00:00:00       0.0
# 2022-09-01 01:00:00       0.0
# 2022-09-01 02:00:00       0.0
# 2022-09-01 03:00:00       0.0
# 2022-09-01 04:00:00       0.0
# ...                       ...
# 2023-01-10 16:00:00       0.3
# 2023-01-10 17:00:00       0.0
# 2023-01-10 18:00:00       0.0
# 2023-01-10 19:00:00       0.0
# 2023-01-10 20:00:00       0.0
#
# [3165 rows x 1 columns]

# %%
fig, ax = plt.subplots(figsize=(8, 3),)
train.plot(ax=ax, label='Training Set', title='Data Train/Test Split')
test.plot(ax=ax, label='Test Set')
ax.axvline(date, color='black', ls='--')
ax.legend(['Training Set', 'Test Set'])
plt.savefig(f"figure2-{dataset_name}.png")
plt.show()

# %%
start_of_week = '01-01-2022'
end_of_week = '01-08-2022'

df.loc[(df.index > start_of_week) & (df.index < end_of_week)] \
    .plot(figsize=(8, 3), title='Week Of Data')

plt.savefig(f"figure3-{dataset_name}.png")
plt.show()

# %%
df.index
# Out:
# DatetimeIndex(['2020-12-22 00:00:00', '2020-12-22 01:00:00',
#                '2020-12-22 02:00:00', '2020-12-22 03:00:00',
#                '2020-12-22 04:00:00', '2020-12-22 05:00:00',
#                '2020-12-22 06:00:00', '2020-12-22 07:00:00',
#                '2020-12-22 08:00:00', '2020-12-22 09:00:00',
#                ...
#                '2023-01-10 11:00:00', '2023-01-10 12:00:00',
#                '2023-01-10 13:00:00', '2023-01-10 14:00:00',
#                '2023-01-10 15:00:00', '2023-01-10 16:00:00',
#                '2023-01-10 17:00:00', '2023-01-10 18:00:00',
#                '2023-01-10 19:00:00', '2023-01-10 20:00:00'],
#               dtype='datetime64[ns]', name='Time', length=17997, freq=None)

# %%
df.index.dayofweek
print(df)
# Out:
#                      prod_k28
# Time
# 2020-12-22 00:00:00       0.0
# 2020-12-22 01:00:00       0.0
# 2020-12-22 02:00:00       0.0
# 2020-12-22 03:00:00       0.0
# 2020-12-22 04:00:00       0.0
# ...                       ...
# 2023-01-10 16:00:00       0.3
# 2023-01-10 17:00:00       0.0
# 2023-01-10 18:00:00       0.0
# 2023-01-10 19:00:00       0.0
# 2023-01-10 20:00:00       0.0
#
# [17997 rows x 1 columns]

# %%
# df.columns

# %%
df
# Out:
#                      prod_k28
# Time
# 2020-12-22 00:00:00       0.0
# 2020-12-22 01:00:00       0.0
# 2020-12-22 02:00:00       0.0
# 2020-12-22 03:00:00       0.0
# 2020-12-22 04:00:00       0.0
# ...                       ...
# 2023-01-10 16:00:00       0.3
# 2023-01-10 17:00:00       0.0
# 2023-01-10 18:00:00       0.0
# 2023-01-10 19:00:00       0.0
# 2023-01-10 20:00:00       0.0
#
# [17997 rows x 1 columns]

# %%
def create_features(df):
    """
    Create time series features based on time series index.
    """
    df = df.copy()
    df['hour'] = df.index.hour
    df['dayofweek'] = df.index.dayofweek
    df['quarter'] = df.index.quarter
    df['month'] = df.index.month
    df['year'] = df.index.year
    df['dayofyear'] = df.index.dayofyear
    df['dayofmonth'] = df.index.day
    df['weekofyear'] = df.index.isocalendar().week
    return df


df = create_features(df)

# %%
df
# Out:
#                      prod_k28  hour  dayofweek  quarter  month  year  \
# Time
# 2020-12-22 00:00:00       0.0     0          1        4     12  2020
# 2020-12-22 01:00:00       0.0     1          1        4     12  2020
# 2020-12-22 02:00:00       0.0     2          1        4     12  2020
# 2020-12-22 03:00:00       0.0     3          1        4     12  2020
# 2020-12-22 04:00:00       0.0     4          1        4     12  2020
# ...                       ...   ...        ...      ...    ...   ...
# 2023-01-10 16:00:00       0.3    16          1        1      1  2023
# 2023-01-10 17:00:00       0.0    17          1        1      1  2023
# 2023-01-10 18:00:00       0.0    18          1        1      1  2023
# 2023-01-10 19:00:00       0.0    19          1        1      1  2023
# 2023-01-10 20:00:00       0.0    20          1        1      1  2023
#
#                      dayofyear  dayofmonth  weekofyear
# Time
# 2020-12-22 00:00:00        357          22          52
# 2020-12-22 01:00:00        357          22          52
# 2020-12-22 02:00:00        357          22          52
# 2020-12-22 03:00:00        357          22          52
# 2020-12-22 04:00:00        357          22          52
# ...                        ...         ...         ...
# 2023-01-10 16:00:00         10          10           2
# 2023-01-10 17:00:00         10          10           2
# 2023-01-10 18:00:00         10          10           2
# 2023-01-10 19:00:00         10          10           2
# 2023-01-10 20:00:00         10          10           2
#
# [17997 rows x 9 columns]

# %%
dataset_name
# Out:
# 'pf_filled'

# %%
fig, ax = plt.subplots(figsize=(8, 3),)
# sns.boxplot(data=df, x='hour', y='PJME_MW')
y_label = selected_column
sns.boxplot(data=df, x='hour', y=y_label)
ax.set_title('KW by Hour')
plt.savefig(f"figure4-{dataset_name}.png")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 3),)
# sns.boxplot(data=df, x='month', y='PJME_MW', palette='Blues')
sns.boxplot(data=df, x='month', y=y_label, palette='Blues')
ax.set_title('KW by Month')
plt.savefig(f"figure5-{dataset_name}.png")
plt.show()
# Out:
# <ipython-input-101-152b059221af>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='month', y=y_label, palette='Blues')

# %%
train = create_features(train)
test = create_features(test)

FEATURES = ['dayofyear', 'hour', 'dayofweek', 'quarter', 'month', 'year']
# TARGET = 'PJME_MW'
TARGET = y_label

X_train = train[FEATURES]
y_train = train[TARGET]

X_test = test[FEATURES]
y_test = test[TARGET]

# %% [markdown]
# # XGboost

# %%
import xgboost as xgb

reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',
                       n_estimators=1000,
                       early_stopping_rounds=50,
                       objective='reg:linear',
                       max_depth=3,
                       learning_rate=0.01)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        verbose=100)
y_pred = reg.predict(X_test)
# Out:
# [0]	validation_0-rmse:6.05599	validation_1-rmse:3.11403
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:20:16] WARNING: /workspace/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [100]	validation_0-rmse:3.77652	validation_1-rmse:2.08502
# [200]	validation_0-rmse:2.96321	validation_1-rmse:1.78657
# [300]	validation_0-rmse:2.64533	validation_1-rmse:1.68299
# [400]	validation_0-rmse:2.50359	validation_1-rmse:1.64496
# [413]	validation_0-rmse:2.49121	validation_1-rmse:1.64718

# %%
plot_act_vs_pred(y_test, y_pred,y_label, 'XGBoot', dataset_name)
# Out:
# RMSE Score on Test set: 1.63
# mae Score on Test set: 1.07
# r2 Score on Test set: 0.70
# mbe Score on Test set: -0.20
# medae Score on Test set: 0.49
# cod Score on Test set: 0.70
# explained_variance Score on Test set: 0.71
# rae Score on Test set: 0.53

# %% [markdown]
# # DNN

# %%
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# Build a deep neural network model using TensorFlow and Keras
model = tf.keras.Sequential([
    tf.keras.layers.Dense(10, activation='relu', input_shape=(6,)),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(1)
])

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
history = model.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test), verbose=1)

# Make predictions on the test set
y_pred = model.predict(X_test)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 691.9390 - val_loss: 29.2013
# Epoch 2/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 39.3777 - val_loss: 26.6767
# Epoch 3/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 32.5985 - val_loss: 18.0017
# Epoch 4/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 29.5814 - val_loss: 10.4348
# Epoch 5/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 30.7911 - val_loss: 11.8204
# Epoch 6/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 32.1392 - val_loss: 9.6911
# Epoch 7/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 30.7442 - val_loss: 40.2005
# Epoch 8/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 29.9540 - val_loss: 11.7898
# Epoch 9/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 32.7870 - val_loss: 11.5780
# Epoch 10/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 30.6646 - val_loss: 9.4891
# Epoch 11/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 30.4411 - val_loss: 12.6962
# Epoch 12/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 30.3244 - val_loss: 10.2287
# Epoch 13/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 29.2868 - val_loss: 12.2311
# Epoch 14/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 31.7462 - val_loss: 11.3797
# Epoch 15/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 32.2960 - val_loss: 14.1352
# Epoch 16/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 29.7458 - val_loss: 21.4079
# Epoch 17/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 30.5450 - val_loss: 12.6491
# Epoch 18/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 30.1733 - val_loss: 9.6033
# Epoch 19/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 29.7268 - val_loss: 10.6945
# Epoch 20/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 30.6183 - val_loss: 12.9860
# Epoch 21/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 31.6140 - val_loss: 18.1999
# Epoch 22/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 31.1812 - val_loss: 18.4389
# Epoch 23/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 31.8187 - val_loss: 9.3435
# Epoch 24/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 30.7880 - val_loss: 9.5139
# Epoch 25/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 29.6943 - val_loss: 9.3539
# Epoch 26/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 30.2458 - val_loss: 9.6319
# Epoch 27/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 30.0127 - val_loss: 9.3989
# Epoch 28/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 30.2352 - val_loss: 12.0098
# Epoch 29/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 28.8389 - val_loss: 8.7949
# Epoch 30/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 28.2475 - val_loss: 8.6498
# Epoch 31/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 26.2015 - val_loss: 26.2691
# Epoch 32/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 28.2753 - val_loss: 15.8831
# Epoch 33/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 27.1588 - val_loss: 9.9835
# Epoch 34/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 26.1128 - val_loss: 28.6163
# Epoch 35/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 26.8408 - val_loss: 8.4527
# Epoch 36/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 25.2223 - val_loss: 10.2043
# Epoch 37/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 25.0474 - val_loss: 33.9131
# Epoch 38/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 26.5623 - val_loss: 8.6697
# Epoch 39/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 27.4191 - val_loss: 7.9680
# Epoch 40/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 24.6617 - val_loss: 7.8678
# Epoch 41/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 25.2161 - val_loss: 12.7315
# Epoch 42/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 24.9051 - val_loss: 15.8259
# Epoch 43/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 26.9325 - val_loss: 21.6184
# Epoch 44/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 26.1146 - val_loss: 19.6429
# Epoch 45/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 25.3546 - val_loss: 8.9315
# Epoch 46/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 25.6216 - val_loss: 9.4891
# Epoch 47/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 25.7690 - val_loss: 8.0676
# Epoch 48/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 25.8005 - val_loss: 7.8883
# Epoch 49/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 24.9040 - val_loss: 9.7953
# Epoch 50/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 25.6797 - val_loss: 11.4560
# Epoch 51/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 24.7780 - val_loss: 10.4654
# Epoch 52/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 24.8261 - val_loss: 9.8863
# Epoch 53/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 25.2091 - val_loss: 9.6029
# Epoch 54/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 26.1549 - val_loss: 8.7600
# Epoch 55/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 27.3042 - val_loss: 16.2030
# Epoch 56/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 24.1150 - val_loss: 7.9043
# Epoch 57/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 26.2372 - val_loss: 9.0848
# Epoch 58/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 25.0974 - val_loss: 11.1676
# Epoch 59/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 24.7995 - val_loss: 12.4267
# Epoch 60/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 24.4821 - val_loss: 25.9974
# Epoch 61/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 25.7408 - val_loss: 8.7994
# Epoch 62/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 24.8860 - val_loss: 18.1652
# Epoch 63/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 24.1882 - val_loss: 11.2039
# Epoch 64/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 25.4818 - val_loss: 8.2126
# Epoch 65/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 25.2476 - val_loss: 9.0777
# Epoch 66/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 23.7281 - val_loss: 7.9737
# Epoch 67/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 24.9073 - val_loss: 8.0853
# Epoch 68/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 24.3457 - val_loss: 8.0788
# Epoch 69/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 25.5626 - val_loss: 8.0335
# Epoch 70/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 24.9246 - val_loss: 8.0531
# Epoch 71/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 26.6683 - val_loss: 11.7140
# Epoch 72/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 25.0155 - val_loss: 12.4962
# Epoch 73/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 24.8713 - val_loss: 7.8429
# Epoch 74/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 24.2122 - val_loss: 8.6782
# Epoch 75/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 24.6020 - val_loss: 8.3050
# Epoch 76/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 24.7036 - val_loss: 8.4699
# Epoch 77/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 24.3912 - val_loss: 9.6672
# Epoch 78/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 23.9805 - val_loss: 9.8845
# Epoch 79/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 26.5033 - val_loss: 8.9975
# Epoch 80/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 24.5948 - val_loss: 8.0077
# Epoch 81/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 24.8344 - val_loss: 10.3386
# Epoch 82/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 24.7625 - val_loss: 8.6539
# Epoch 83/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 24.2862 - val_loss: 9.7066
# Epoch 84/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 25.4740 - val_loss: 9.3012
# Epoch 85/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 24.9831 - val_loss: 12.7341
# Epoch 86/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 24.9984 - val_loss: 13.9757
# Epoch 87/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 25.2587 - val_loss: 7.9310
# Epoch 88/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 23.4794 - val_loss: 10.3868
# Epoch 89/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 25.0167 - val_loss: 10.2191
# Epoch 90/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 24.2670 - val_loss: 8.4113
# Epoch 91/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 24.4588 - val_loss: 15.1861
# Epoch 92/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 24.3613 - val_loss: 17.2236
# Epoch 93/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 24.4803 - val_loss: 8.0391
# Epoch 94/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 23.4443 - val_loss: 7.9676
# Epoch 95/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 23.6212 - val_loss: 8.0483
# Epoch 96/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 24.5734 - val_loss: 15.1760
# Epoch 97/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 23.9905 - val_loss: 8.8965
# Epoch 98/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 24.0417 - val_loss: 9.5276
# Epoch 99/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 23.2879 - val_loss: 8.4713
# Epoch 100/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 24.0650 - val_loss: 10.7597
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
# Visualize the training loss and validation loss over epochs
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plot_act_vs_pred(y_test, y_pred,y_label, 'DNN', dataset_name)
# Out:
# RMSE Score on Test set: 3.28
# mae Score on Test set: 2.64
# r2 Score on Test set: -0.19
# mbe Score on Test set: -1.66
# medae Score on Test set: 2.37
# cod Score on Test set: -0.19
# explained_variance Score on Test set: 0.11
# rae Score on Test set: 1.31

# %% [markdown]
# # DNN Parameter Tuning using GA:

# %%
# !pip install deap
# Out:
# Requirement already satisfied: deap in /usr/local/lib/python3.10/dist-packages (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from deap) (1.26.4)

# %%
# !pip install pyswarm
# Out:
# Requirement already satisfied: pyswarm in /usr/local/lib/python3.10/dist-packages (0.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pyswarm) (1.26.4)

# %%
no_optimizatin_epochs = 10
evaluation_epochs = 10
ga_population_size = 10
ga_ngen = 10
pso_swarm_size = 10
pso_maxiter = 10
best_model_pso_epochs = 100

# %%
import random
import numpy as np
from deap import base, creator, tools, algorithms
import tensorflow as tf
from tensorflow import keras

# Define the fitness function
nfe = 0
def evaluate(individual):
    global nfe
    nfe += 1
    print(nfe)
    individual[0] = int(individual[0])
    individual[1] = int(individual[1])
    print('first layer: ', individual[0])
    print('second layer: ', individual[1])
    # Define the architecture of the neural network based on the individual's genes
    model = keras.Sequential()
    # print('**** Shape: ', X_train.shape)
    model.add(keras.layers.Dense(int(individual[0]), activation='relu', input_shape=(X_train.shape[1],)))
    model.add(keras.layers.Dense(int(individual[1]), activation='relu'))
    model.add(keras.layers.Dense(1))

    # Compile the model
    model.compile(optimizer='adam', loss='mean_squared_error')

    # Train and evaluate the model
    history = model.fit(X_train, y_train, epochs=evaluation_epochs, validation_data=(X_test, y_test), verbose=0)
    loss = history.history['val_loss'][-1]

    return (loss,)

# Create a fitness function maximizing minimization
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", list, fitness=creator.FitnessMin)

# Create a toolbox for GA
toolbox_ga = base.Toolbox()
toolbox_ga.register("attr_int", random.randint, 16, 128)  # For the number of neurons in layers
toolbox_ga.register("individual", tools.initRepeat, creator.Individual, toolbox_ga.attr_int, n=2)
toolbox_ga.register("population", tools.initRepeat, list, toolbox_ga.individual)

toolbox_ga.register("evaluate", evaluate)
toolbox_ga.register("mate", tools.cxTwoPoint)
toolbox_ga.register("mutate", tools.mutUniformInt, low=16, up=128, indpb=0.2)
toolbox_ga.register("select", tools.selTournament, tournsize=3)

# Define your X_train and Y_train datasets here

# Create the initial GA population
ga_population = toolbox_ga.population(n=ga_population_size)

# Run the genetic algorithm
algorithms.eaSimple(ga_population, toolbox_ga, cxpb=0.7, mutpb=0.2, ngen=ga_ngen, verbose=True)

# Get the best individual from the GA population
best_individual_ga = tools.selBest(ga_population, k=1)[0]

# Create a PSO population with the best GA individual as the initial particle
from pyswarm import pso

def pso_optimization(individual):
    loss = evaluate(individual)[0]
    return loss

# Convert the GA individual to a PSO-friendly format (list of integers)
best_individual_pso = [int(best_individual_ga[0]), int(best_individual_ga[1])]

# Define the bounds for PSO
lb = [16, 16]
ub = [128, 128]

# Run PSO with the best GA individual as the initial particle
x_opt, f_opt = pso(pso_optimization, lb, ub, swarmsize=pso_swarm_size, maxiter=pso_maxiter)

# Print the results
print("Best architecture found by PSO:", x_opt)
print("Best architecture found by PSO (rounded):", [int(x_opt[0]), int(x_opt[1])])

# Train and evaluate the best model with the architecture found by PSO
best_model_pso = keras.Sequential()
best_model_pso.add(keras.layers.Dense(int(x_opt[0]), activation='relu', input_shape=(X_train.shape[1],)))
best_model_pso.add(keras.layers.Dense(int(x_opt[1]), activation='relu'))
best_model_pso.add(keras.layers.Dense(1))
best_model_pso.compile(optimizer='adam', loss='mean_squared_error')

history2 = best_model_pso.fit(X_train, y_train, epochs=best_model_pso_epochs, verbose=1, validation_data=(X_test, y_test))
test_loss = best_model_pso.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss}")
# Out:
# /usr/local/lib/python3.10/dist-packages/deap/creator.py:185: RuntimeWarning: A class named 'FitnessMin' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# /usr/local/lib/python3.10/dist-packages/deap/creator.py:185: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1
# first layer:  63
# second layer:  110
# 2
# first layer:  41
# second layer:  50
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 3
# first layer:  124
# second layer:  55
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4
# first layer:  26
# second layer:  101
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 5
# first layer:  58
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 6
# first layer:  67
# second layer:  36
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 7
# first layer:  128
# second layer:  122
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8
# first layer:  52
# second layer:  65
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 9
# first layer:  24
# second layer:  53
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 10
# first layer:  81
# second layer:  16
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# gen	nevals
# 0  	10
# 11
# first layer:  58
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 12
# first layer:  58
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 13
# first layer:  124
# second layer:  72
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 14
# first layer:  26
# second layer:  55
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 15
# first layer:  81
# second layer:  101
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 16
# first layer:  26
# second layer:  16
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1  	6
# 17
# first layer:  67
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 18
# first layer:  58
# second layer:  36
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 19
# first layer:  58
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 20
# first layer:  58
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 21
# first layer:  58
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 22
# first layer:  58
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 23
# first layer:  58
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 24
# first layer:  58
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 25
# first layer:  58
# second layer:  92
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 26
# first layer:  58
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2  	10
# 27
# first layer:  58
# second layer:  36
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 28
# first layer:  73
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 29
# first layer:  58
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 30
# first layer:  67
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 31
# first layer:  58
# second layer:  92
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32
# first layer:  58
# second layer:  36
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 33
# first layer:  67
# second layer:  36
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 34
# first layer:  58
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 3  	8
# 35
# first layer:  67
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 36
# first layer:  58
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 37
# first layer:  73
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38
# first layer:  67
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 39
# first layer:  73
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 40
# first layer:  67
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 41
# first layer:  67
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 42
# first layer:  77
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 43
# first layer:  58
# second layer:  92
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4  	9
# 44
# first layer:  67
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45
# first layer:  73
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 46
# first layer:  67
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 47
# first layer:  67
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 48
# first layer:  67
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 49
# first layer:  77
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 50
# first layer:  67
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 51
# first layer:  67
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 52
# first layer:  67
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 5  	9
# 53
# first layer:  67
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 54
# first layer:  73
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 55
# first layer:  77
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 56
# first layer:  67
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 57
# first layer:  67
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 58
# first layer:  67
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 59
# first layer:  67
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 60
# first layer:  67
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 61
# first layer:  73
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 62
# first layer:  67
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 6  	10
# 63
# first layer:  67
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 64
# first layer:  73
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 65
# first layer:  67
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 66
# first layer:  73
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 67
# first layer:  67
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 7  	5
# 68
# first layer:  67
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 69
# first layer:  73
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 70
# first layer:  67
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 71
# first layer:  73
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 72
# first layer:  67
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 73
# first layer:  67
# second layer:  31
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 74
# first layer:  67
# second layer:  75
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 75
# first layer:  67
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8  	8
# 76
# first layer:  73
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 77
# first layer:  73
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 78
# first layer:  73
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 79
# first layer:  73
# second layer:  75
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 80
# first layer:  67
# second layer:  127
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 81
# first layer:  67
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 82
# first layer:  67
# second layer:  75
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 83
# first layer:  67
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 84
# first layer:  67
# second layer:  17
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 9  	9
# 85
# first layer:  17
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 86
# first layer:  73
# second layer:  57
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 87
# first layer:  73
# second layer:  75
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 88
# first layer:  67
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 89
# first layer:  73
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 90
# first layer:  73
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 91
# first layer:  73
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 92
# first layer:  67
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 93
# first layer:  73
# second layer:  75
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 94
# first layer:  73
# second layer:  125
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 10 	10
# 95
# first layer:  52.0
# second layer:  117.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 96
# first layer:  42.0
# second layer:  89.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 97
# first layer:  106.0
# second layer:  18.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 98
# first layer:  89.0
# second layer:  100.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 99
# first layer:  102.0
# second layer:  52.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 100
# first layer:  34.0
# second layer:  118.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 101
# first layer:  33.0
# second layer:  26.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 102
# first layer:  28.0
# second layer:  50.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 103
# first layer:  78.0
# second layer:  50.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 104
# first layer:  71.0
# second layer:  87.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 105
# first layer:  70.0
# second layer:  72.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 106
# first layer:  83.0
# second layer:  39.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 107
# first layer:  48.0
# second layer:  69.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 108
# first layer:  114.0
# second layer:  71.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 109
# first layer:  97.0
# second layer:  36.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 110
# first layer:  27.0
# second layer:  58.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 111
# first layer:  76.0
# second layer:  49.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 112
# first layer:  16.0
# second layer:  28.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 113
# first layer:  99.0
# second layer:  87.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 114
# first layer:  42.0
# second layer:  115.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 115
# first layer:  78.0
# second layer:  69.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 116
# first layer:  79.0
# second layer:  30.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 117
# first layer:  26.0
# second layer:  96.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 118
# first layer:  118.0
# second layer:  74.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 119
# first layer:  101.0
# second layer:  41.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 120
# first layer:  64.0
# second layer:  29.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 121
# first layer:  105.0
# second layer:  70.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 122
# first layer:  37.0
# second layer:  36.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 123
# first layer:  109.0
# second layer:  99.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 124
# first layer:  39.0
# second layer:  112.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 125
# first layer:  90.0
# second layer:  91.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 126
# first layer:  72.0
# second layer:  44.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 127
# first layer:  31.0
# second layer:  101.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 128
# first layer:  119.0
# second layer:  78.0
# ...
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 188
# first layer:  110.0
# second layer:  87.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 189
# first layer:  106.0
# second layer:  88.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 190
# first layer:  107.0
# second layer:  88.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 191
# first layer:  105.0
# second layer:  83.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 192
# first layer:  93.0
# second layer:  84.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 193
# first layer:  106.0
# second layer:  89.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 194
# first layer:  107.0
# second layer:  88.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 195
# first layer:  103.0
# second layer:  85.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 196
# first layer:  92.0
# second layer:  100.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 197
# first layer:  80.0
# second layer:  84.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 198
# first layer:  112.0
# second layer:  87.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 199
# first layer:  107.0
# second layer:  89.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 200
# first layer:  105.0
# second layer:  87.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 201
# first layer:  109.0
# second layer:  83.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 202
# first layer:  81.0
# second layer:  81.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 203
# first layer:  107.0
# second layer:  91.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 204
# first layer:  106.0
# second layer:  89.0
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Stopping search: maximum iterations reached --> 10
# Best architecture found by PSO: [108.  89.]
# Best architecture found by PSO (rounded): [108, 89]
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 708.5823 - val_loss: 7.9808
# Epoch 2/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 26.8257 - val_loss: 10.4454
# Epoch 3/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 25.4885 - val_loss: 45.4080
# Epoch 4/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 30.6990 - val_loss: 7.9312
# Epoch 5/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 28.6152 - val_loss: 9.7023
# Epoch 6/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 26.3642 - val_loss: 13.4057
# Epoch 7/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 34.9594 - val_loss: 8.7902
# Epoch 8/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 30.6121 - val_loss: 9.8892
# Epoch 9/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 28.2220 - val_loss: 10.3166
# Epoch 10/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 27.4274 - val_loss: 9.4275
# Epoch 11/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 27.8701 - val_loss: 8.9653
# Epoch 12/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 28.0119 - val_loss: 12.6765
# Epoch 13/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 28.6067 - val_loss: 8.4812
# Epoch 14/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 27.1789 - val_loss: 27.1673
# Epoch 15/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 30.2194 - val_loss: 20.3074
# Epoch 16/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 25.6180 - val_loss: 6.8264
# Epoch 17/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 22.2650 - val_loss: 15.6289
# Epoch 18/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 18.8833 - val_loss: 8.6297
# Epoch 19/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 16.3061 - val_loss: 9.8749
# Epoch 20/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 15.3372 - val_loss: 6.9942
# Epoch 21/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 13.9301 - val_loss: 7.2053
# Epoch 22/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 13.5700 - val_loss: 17.7728
# Epoch 23/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 14.0205 - val_loss: 6.2040
# Epoch 24/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 15.2863 - val_loss: 6.5529
# Epoch 25/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 13.6488 - val_loss: 8.9939
# Epoch 26/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 13.8222 - val_loss: 6.0753
# Epoch 27/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 13.0373 - val_loss: 6.3827
# Epoch 28/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 11.9777 - val_loss: 20.4512
# Epoch 29/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 13.3301 - val_loss: 6.5114
# Epoch 30/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 11.6494 - val_loss: 6.1271
# Epoch 31/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 13.1139 - val_loss: 6.7524
# Epoch 32/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 12.6394 - val_loss: 7.1481
# Epoch 33/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 11.2423 - val_loss: 5.9558
# Epoch 34/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 11.2351 - val_loss: 5.9389
# Epoch 35/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 10.6350 - val_loss: 6.4911
# Epoch 36/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 11.8948 - val_loss: 5.4194
# Epoch 37/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 10.3361 - val_loss: 6.3039
# Epoch 38/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 10.3141 - val_loss: 5.1761
# Epoch 39/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.3580 - val_loss: 4.7167
# Epoch 40/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.2222 - val_loss: 4.8606
# Epoch 41/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 7.7768 - val_loss: 4.7712
# Epoch 42/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 7.8002 - val_loss: 3.6487
# Epoch 43/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 7.6304 - val_loss: 5.2732
# Epoch 44/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.7417 - val_loss: 3.7249
# Epoch 45/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.2118 - val_loss: 3.8725
# Epoch 46/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 7.5753 - val_loss: 2.5977
# Epoch 47/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 7.5641 - val_loss: 3.3198
# Epoch 48/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.9578 - val_loss: 2.8925
# Epoch 49/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.7909 - val_loss: 2.1949
# Epoch 50/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.5469 - val_loss: 3.5481
# Epoch 51/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.5703 - val_loss: 2.3410
# Epoch 52/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 7.0823 - val_loss: 3.3440
# Epoch 53/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.3657 - val_loss: 2.2217
# Epoch 54/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.3014 - val_loss: 2.0875
# Epoch 55/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 6.5735 - val_loss: 4.5180
# Epoch 56/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.5924 - val_loss: 1.9227
# Epoch 57/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.4107 - val_loss: 2.0751
# Epoch 58/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.6706 - val_loss: 2.1688
# Epoch 59/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.3823 - val_loss: 1.9384
# Epoch 60/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.4754 - val_loss: 2.9921
# Epoch 61/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.4236 - val_loss: 1.9186
# Epoch 62/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.2422 - val_loss: 2.1147
# Epoch 63/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.2857 - val_loss: 2.4469
# Epoch 64/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.7512 - val_loss: 2.1120
# Epoch 65/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.7174 - val_loss: 2.3514
# Epoch 66/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 6.2090 - val_loss: 2.2208
# Epoch 67/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.3791 - val_loss: 3.1440
# Epoch 68/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 6.5609 - val_loss: 1.9945
# Epoch 69/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.4598 - val_loss: 2.1494
# Epoch 70/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.0757 - val_loss: 2.8516
# Epoch 71/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.1402 - val_loss: 2.1601
# Epoch 72/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.1310 - val_loss: 2.4415
# Epoch 73/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.2739 - val_loss: 2.6149
# Epoch 74/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.1939 - val_loss: 1.9823
# Epoch 75/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.0094 - val_loss: 2.1234
# Epoch 76/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.6227 - val_loss: 2.1979
# Epoch 77/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6.1588 - val_loss: 2.7387
# Epoch 78/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6.1243 - val_loss: 2.1380
# Epoch 79/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 6.4831 - val_loss: 2.6075
# Epoch 80/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5.9824 - val_loss: 2.8221
# Epoch 81/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.4207 - val_loss: 1.9778
# Epoch 82/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.2575 - val_loss: 2.3046
# Epoch 83/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.0680 - val_loss: 2.0010
# Epoch 84/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.2136 - val_loss: 2.3048
# Epoch 85/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.0064 - val_loss: 2.5127
# Epoch 86/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.0776 - val_loss: 2.5717
# Epoch 87/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 6.3453 - val_loss: 2.1333
# Epoch 88/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.1584 - val_loss: 2.9213
# Epoch 89/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.0135 - val_loss: 2.4685
# Epoch 90/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 6.1766 - val_loss: 2.2142
# Epoch 91/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.0522 - val_loss: 2.2097
# Epoch 92/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.2921 - val_loss: 2.0333
# Epoch 93/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.0964 - val_loss: 3.0629
# Epoch 94/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.2013 - val_loss: 2.3201
# Epoch 95/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.1499 - val_loss: 2.5939
# Epoch 96/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.4875 - val_loss: 2.2012
# Epoch 97/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.1768 - val_loss: 2.0300
# Epoch 98/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5.8943 - val_loss: 2.5630
# Epoch 99/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.1530 - val_loss: 2.1133
# Epoch 100/100
# 464/464 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.0136 - val_loss: 2.1561
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1311
# Test Loss: 2.1560723781585693

# %%
# Make predictions
y_pred = best_model_pso.predict(X_test)
# Out:
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
plot_act_vs_pred(y_test, y_pred,y_label, 'DNN-GA-PSO', dataset_name)
# Out:
# RMSE Score on Test set: 1.47
# mae Score on Test set: 0.71
# r2 Score on Test set: 0.76
# mbe Score on Test set: 0.19
# medae Score on Test set: 0.03
# cod Score on Test set: 0.76
# explained_variance Score on Test set: 0.76
# rae Score on Test set: 0.35
